# %%
# !nvidia-smi
# Out:
# Tue Jul 11 04:48:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 43.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 104.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 5.7 MB/s eta 0:00:00

# %%
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer, pipeline
import torch

model = "tiiuae/falcon-7b-instruct" #tiiuae/falcon-40b-instruct

tokenizer = AutoTokenizer.from_pretrained(model)

# pipeline = pipeline(
#     "text-generation", #task
#     model=model,
#     tokenizer=tokenizer,
#     torch_dtype=torch.bfloat16,
#     trust_remote_code=True,
#     device_map="auto",
#     max_length=200,
#     do_sample=True,
#     top_k=10,
#     num_return_sequences=1,
#     eos_token_id=tokenizer.eos_token_id
# )
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - configuration_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - modelling_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# ...

# %%
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0.4}) #temp defines the randomness in the output. zero mans no creativity and on point.

# %%
from langchain import PromptTemplate,  LLMChain

template = """
You are an intelligent chatbot. Help the following question with brilliant answers.
Question: {question}
Answer:"""
prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

question = "Explain what is Artificial Intellience as Nursery Rhymes "

print(llm_chain.run(question))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1259: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
#  Artificial Intelligence (AI) is like a giant playground with a lot of robots. AI is learning how these robots think, and helping them to think even better. It can also help you do things that you might not think you could do. It's like having a robot tutor that can answer all your questions, make suggestions, and help you with tasks.
#
# Question:

# %%
print(llm_chain.run(question))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Artificial intelligence can be described
# As the nursery rhymes so delightful.
# It can solve complex problems with ease,
# Helping us in life to find relief.
#
# It's amazing how a machine can learn,
# And with the knowledge, it can perform.
# It can analyze large amounts of data,
# And answer questions so cleverly, it seems.
#
# Artificial intelligence has made our lives easier,
# With its many features and abilities.
# From medical diagnostics to financial decisions,
# It helps us make better decisions.
#
# It's an intelligent machine we can rely on,
# With capabilities that are so profound.
# From facial recognition to natural language processing,
# It helps us in many ways, without ceasing to improve.
#
#
# So, artificial intelligence is the new way to

# %%
question_2= "Output top 5 fotballlers in the last decade"
print(llm_chain.run(question_2))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
#  Cristiano Ronaldo, Lionel Messi, Ronaldo, Messi, Zlatan Ibrahimovic
# 1. Ronaldo: A top footballing talent with a unique style of playing. He has achieved a lot throughout his career, including scoring over 800 goals in just over 800 games, which is incredible when compared to many greats in the sport. He is a true icon of the sport and his performances on the field will be remembered for decades.
# 2. Lionel Messi: Another all-time great of the sport, Messi is a master of the technical aspects of footballing. He has a great understanding of the game and is a great dribbler, which has allowed him to achieve a lot in his illustrious career. He is considered to be one of the best soccer players of all time.
# 3. Ronaldo: The Portuguese superstar

# %%
question_3 = "What is the importance of temperature in Langchain "
print(llm_chain.run(question_3))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
#  Temperature is very important in Langchain. Temperature control is necessary for the efficient functioning of various systems and machinery, including air conditioning systems, refrigeration units, and industrial processes. It is necessary to maintain proper temperature to prevent the breakdown of equipment, reduce energy consumption, and improve the quality of processes. Additionally, temperature can play an important role in determining the lifespan and performance of components, such as lubricants and bearings. It is critical to monitor and maintain a proper temperature range to ensure optimal performance and avoid costly repairs.
